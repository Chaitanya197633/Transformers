# %% [markdown]
# # Final Training Pipeline
# Feature-extraction + MLP deep compression workflow (no CNN training).

# %% [markdown]
# ## Setup (run once per new kernel)
# Install dependencies in the active notebook kernel, then restart kernel.

# %%
# %pip install -r requirements.txt

# %%
from main import run_pipeline
metrics = run_pipeline()
metrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from main import run_pipeline
#       2 metrics = run_pipeline()
#       3 metrics
#
# File c:\Users\ASUS\OneDrive\ドキュメント\GitHub\Transformers\main.py:6
#       3 import random
#       5 import numpy as np
# ----> 6 import torch
#       8 from compression import (
#       9     apply_magnitude_pruning,
#      10     global_sparsity,
#      11     quantize_model_weights,
#      12     replace_linear_layers,
#      13 )
#      14 from config import DEFAULT_CONFIG
#
# ModuleNotFoundError: No module named 'torch'
