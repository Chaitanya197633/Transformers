# %% [markdown]
# # Final Training Pipeline
# Feature-extraction + MLP compression workflow (no CNN training).

# %% [markdown]
# ## Setup
# Install dependencies in the active kernel, then restart kernel.

# %%
# %pip install -r requirements.txt

# %% [markdown]
# If PyTorch fails with DLL errors (e.g., WinError 1114), the pipeline automatically falls back to a NumPy backend.

# %%
from main import run_pipeline
metrics = run_pipeline()
metrics
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 2
#       1 from main import run_pipeline
# ----> 2 metrics = run_pipeline()
#       3 metrics
#
# File c:\Users\ASUS\OneDrive\ドキュメント\GitHub\Transformers\main.py:41, in run_pipeline()
#      38 _ensure_runtime_dependencies()
#      40 import numpy as np
# ---> 41 import torch
#      43 from compression import (
#      44     apply_magnitude_pruning,
#      45     global_sparsity,
#      46     quantize_model_weights,
#      47     replace_linear_layers,
#      48 )
#      49 from data import build_feature_dataloaders
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\torch\__init__.py:280
#     276                     raise err
#     278         kernel32.SetErrorMode(prev_error_mode)
# --> 280     _load_dll_libraries()
#     281     del _load_dll_libraries
# ...
